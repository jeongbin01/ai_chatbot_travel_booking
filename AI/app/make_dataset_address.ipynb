# %%
import pandas as pd
from openai import OpenAI
from sqlalchemy import create_engine, Column, String, MetaData, Table
from pgvector.sqlalchemy import Vector
import os
from dotenv import load_dotenv

load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
# CSV 읽기
df = pd.read_csv("./국토교통부_전국 법정동_20250415.csv")

# 조건 1: 시군구명은 NaN이 아니고, 읍면동명은 NaN
filtered_df = df[df["읍면동명"].isna()]

# 시도 코드 / 시군구 코드 추출
filtered_df["시도코드"] = filtered_df["법정동코드"].astype(str).str[:2]
filtered_df["시군구코드"] = filtered_df["법정동코드"].astype(str).str[2:5]

# 조건 2: 서울, 부산, 제주, 인천, 강릉만 남기기
keep_sido = ["서울특별시", "부산광역시", "제주특별자치도", "인천광역시"]
keep_sigungu = ["강릉시"]

final_df = filtered_df[
    (filtered_df["시도명"].isin(keep_sido)) |
    (filtered_df["시군구명"].isin(keep_sigungu))
]
# print(final_df)
# 시도명과 시군구명 합치기
final_df["시도_시군구"] = final_df["시도명"].fillna("") + " " + final_df["시군구명"].fillna("")

# 필요한 컬럼 순서대로 재배치
final_df = final_df[["시도코드", "시군구코드", "시도_시군구"]]

final_df = final_df.reset_index(drop=True)
print(final_df)
# Out:
#    시도코드 시군구코드        시도_시군구
# 0    11   000        서울특별시
# 1    11   110     서울특별시 종로구
# 2    11   140      서울특별시 중구
# 3    11   170     서울특별시 용산구
# 4    11   200     서울특별시 성동구
# ..  ...   ...           ...
# 60   42   150       강원도 강릉시
# 61   50   000      제주특별자치도
# 62   50   110   제주특별자치도 제주시
# 63   50   130  제주특별자치도 서귀포시
# 64   51   150   강원특별자치도 강릉시
#
# [65 rows x 3 columns]
# /tmp/ipykernel_1702/3784374850.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["시도코드"] = filtered_df["법정동코드"].astype(str).str[:2]
# /tmp/ipykernel_1702/3784374850.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["시군구코드"] = filtered_df["법정동코드"].astype(str).str[2:5]
# /tmp/ipykernel_1702/3784374850.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["시도_시군구"] = final_df["시도명"].fillna("") + " " + final_df["시군구명"].fillna("")

# %%
from sqlalchemy import create_engine, MetaData, Table, Column, String
from pgvector.sqlalchemy import Vector

engine = create_engine("postgresql+psycopg2://postgres:1234@localhost:5432/postgres")

metadata = MetaData()

embeddings = []
for text in final_df["시도_시군구"]:
    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=text
    )
    embeddings.append(response.data[0].embedding)

dimension = len(embeddings[0])

table = Table(
    "city_regions",
    metadata,
    Column("city_code1", String),
    Column("city_code2", String),
    Column("city_str", String),
    Column("embedding", Vector(dimension))
)

metadata.create_all(engine)

# 5. 데이터 삽입
with engine.connect() as conn:
    for i, row in final_df.iterrows():
        print(i, row)
        # conn.execute(
        #     table.insert().values(
        #         city_code1=row["city_code1"],
        #         city_code2=row["city_code2"],
        #         city_str=row["city_str"],
        #         embedding=embeddings[i]
        #     )
        # )
# Out:
# 0 시도코드          11
# 시군구코드        000
# 시도_시군구    서울특별시
# Name: 0, dtype: object
# 1 시도코드             11
# 시군구코드           110
# 시도_시군구    서울특별시 종로구
# Name: 1, dtype: object
# 2 시도코드            11
# 시군구코드          140
# 시도_시군구    서울특별시 중구
# Name: 2, dtype: object
# 3 시도코드             11
# 시군구코드           170
# 시도_시군구    서울특별시 용산구
# Name: 3, dtype: object
# 4 시도코드             11
# 시군구코드           200
# 시도_시군구    서울특별시 성동구
# Name: 4, dtype: object
# 5 시도코드             11
# 시군구코드           215
# 시도_시군구    서울특별시 광진구
# Name: 5, dtype: object
# 6 시도코드              11
# 시군구코드            230
# 시도_시군구    서울특별시 동대문구
# Name: 6, dtype: object
# 7 시도코드             11
# 시군구코드           260
# 시도_시군구    서울특별시 중랑구
# Name: 7, dtype: object
# 8 시도코드             11
# 시군구코드           290
# 시도_시군구    서울특별시 성북구
# Name: 8, dtype: object
# 9 시도코드             11
# 시군구코드           305
# 시도_시군구    서울특별시 강북구
# Name: 9, dtype: object
# 10 시도코드             11
# 시군구코드           320
# 시도_시군구    서울특별시 도봉구
# Name: 10, dtype: object
# 11 시도코드             11
# 시군구코드           350
# 시도_시군구    서울특별시 노원구
# Name: 11, dtype: object
# 12 시도코드             11
# 시군구코드           380
# 시도_시군구    서울특별시 은평구
# Name: 12, dtype: object
# 13 시도코드              11
# 시군구코드            410
# 시도_시군구    서울특별시 서대문구
# Name: 13, dtype: object
# 14 시도코드             11
# 시군구코드           440
# 시도_시군구    서울특별시 마포구
# Name: 14, dtype: object
# 15 시도코드             11
# 시군구코드           470
# 시도_시군구    서울특별시 양천구
# Name: 15, dtype: object
# 16 시도코드             11
# 시군구코드           500
# 시도_시군구    서울특별시 강서구
# Name: 16, dtype: object
# 17 시도코드             11
# 시군구코드           530
# 시도_시군구    서울특별시 구로구
# Name: 17, dtype: object
# 18 시도코드             11
# 시군구코드           545
# 시도_시군구    서울특별시 금천구
# Name: 18, dtype: object
# 19 시도코드              11
# 시군구코드            560
# 시도_시군구    서울특별시 영등포구
# Name: 19, dtype: object
# 20 시도코드             11
# 시군구코드           590
# 시도_시군구    서울특별시 동작구
# Name: 20, dtype: object
# 21 시도코드             11
# 시군구코드           620
# 시도_시군구    서울특별시 관악구
# Name: 21, dtype: object
# 22 시도코드             11
# 시군구코드           650
# 시도_시군구    서울특별시 서초구
# Name: 22, dtype: object
# 23 시도코드             11
# 시군구코드           680
# 시도_시군구    서울특별시 강남구
# Name: 23, dtype: object
# 24 시도코드             11
# 시군구코드           710
# 시도_시군구    서울특별시 송파구
# Name: 24, dtype: object
# 25 시도코드             11
# 시군구코드           740
# 시도_시군구    서울특별시 강동구
# Name: 25, dtype: object
# 26 시도코드          26
# 시군구코드        000
# 시도_시군구    부산광역시
# Name: 26, dtype: object
# 27 시도코드            26
# 시군구코드          110
# 시도_시군구    부산광역시 중구
# Name: 27, dtype: object
# 28 시도코드            26
# 시군구코드          140
# 시도_시군구    부산광역시 서구
# Name: 28, dtype: object
# 29 시도코드            26
# 시군구코드          170
# 시도_시군구    부산광역시 동구
# Name: 29, dtype: object
# 30 시도코드             26
# 시군구코드           200
# 시도_시군구    부산광역시 영도구
# Name: 30, dtype: object
# 31 시도코드              26
# 시군구코드            230
# 시도_시군구    부산광역시 부산진구
# Name: 31, dtype: object
# 32 시도코드             26
# 시군구코드           260
# 시도_시군구    부산광역시 동래구
# Name: 32, dtype: object
# 33 시도코드            26
# 시군구코드          290
# 시도_시군구    부산광역시 남구
# Name: 33, dtype: object
# 34 시도코드            26
# 시군구코드          320
# 시도_시군구    부산광역시 북구
# Name: 34, dtype: object
# 35 시도코드              26
# 시군구코드            350
# 시도_시군구    부산광역시 해운대구
# Name: 35, dtype: object
# 36 시도코드             26
# 시군구코드           380
# 시도_시군구    부산광역시 사하구
# Name: 36, dtype: object
# 37 시도코드             26
# 시군구코드           410
# 시도_시군구    부산광역시 금정구
# Name: 37, dtype: object
# 38 시도코드             26
# 시군구코드           440
# 시도_시군구    부산광역시 강서구
# Name: 38, dtype: object
# 39 시도코드             26
# 시군구코드           470
# 시도_시군구    부산광역시 연제구
# Name: 39, dtype: object
# 40 시도코드             26
# 시군구코드           500
# 시도_시군구    부산광역시 수영구
# Name: 40, dtype: object
# 41 시도코드             26
# 시군구코드           530
# 시도_시군구    부산광역시 사상구
# Name: 41, dtype: object
# 42 시도코드             26
# 시군구코드           710
# 시도_시군구    부산광역시 기장군
# Name: 42, dtype: object
# 43 시도코드          28
# 시군구코드        000
# 시도_시군구    인천광역시
# Name: 43, dtype: object
# 44 시도코드            28
# 시군구코드          110
# 시도_시군구    인천광역시 중구
# Name: 44, dtype: object
# 45 시도코드                28
# 시군구코드              115
# 시도_시군구    인천광역시 중구영종출장
# Name: 45, dtype: object
# 46 시도코드                28
# 시군구코드              116
# 시도_시군구    인천광역시 중구용유출장
# Name: 46, dtype: object
# 47 시도코드            28
# 시군구코드          140
# 시도_시군구    인천광역시 동구
# Name: 47, dtype: object
# 48 시도코드            28
# 시군구코드          170
# 시도_시군구    인천광역시 남구
# Name: 48, dtype: object
# 49 시도코드              28
# 시군구코드            177
# 시도_시군구    인천광역시 미추홀구
# Name: 49, dtype: object
# 50 시도코드             28
# 시군구코드           185
# 시도_시군구    인천광역시 연수구
# Name: 50, dtype: object
# 51 시도코드             28
# 시군구코드           200
# 시도_시군구    인천광역시 남동구
# Name: 51, dtype: object
# 52 시도코드            28
# 시군구코드          230
# 시도_시군구    인천광역시 북구
# Name: 52, dtype: object
# 53 시도코드                28
# 시군구코드              235
# 시도_시군구    인천광역시 북구계양출장
# Name: 53, dtype: object
# 54 시도코드             28
# 시군구코드           237
# 시도_시군구    인천광역시 부평구
# Name: 54, dtype: object
# 55 시도코드             28
# 시군구코드           245
# 시도_시군구    인천광역시 계양구
# Name: 55, dtype: object
# 56 시도코드            28
# 시군구코드          260
# 시도_시군구    인천광역시 서구
# Name: 56, dtype: object
# 57 시도코드                28
# 시군구코드              265
# 시도_시군구    인천광역시 서구검단출장
# Name: 57, dtype: object
# 58 시도코드             28
# 시군구코드           710
# 시도_시군구    인천광역시 강화군
# Name: 58, dtype: object
# 59 시도코드             28
# 시군구코드           720
# 시도_시군구    인천광역시 옹진군
# Name: 59, dtype: object
# 60 시도코드           42
# 시군구코드         150
# 시도_시군구    강원도 강릉시
# Name: 60, dtype: object
# 61 시도코드            50
# 시군구코드          000
# 시도_시군구    제주특별자치도
# Name: 61, dtype: object
# 62 시도코드               50
# 시군구코드             110
# 시도_시군구    제주특별자치도 제주시
# Name: 62, dtype: object
# 63 시도코드                50
# 시군구코드              130
# 시도_시군구    제주특별자치도 서귀포시
# Name: 63, dtype: object
# 64 시도코드               51
# 시군구코드             150
# 시도_시군구    강원특별자치도 강릉시
# Name: 64, dtype: object

# %%
from sqlalchemy import insert

with engine.connect() as conn:
    for (idx, row), embedding in zip(final_df.iterrows(), embeddings):
        stmt = insert(table).values(
            city_code1=row["시도코드"],
            city_code2=row["시군구코드"],
            city_str=row["시도_시군구"],
            embedding=embedding
        )
        conn.execute(stmt)
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/teamproj-ilPeYRYx-py3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city_code1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 6
#       3 with engine.connect() as conn:
#       4     for (idx, row), embedding in zip(final_df.iterrows(), embeddings):
#       5         stmt = insert(table).values(
# ----> 6             city_code1=row["city_code1"],
#       7             city_code2=row["city_code2"],
#       8             city_str=row["city_str"],
#       9             embedding=embedding
#      10         )
#      11         conn.execute(stmt)
#      12     conn.commit()
#
# File ~/.cache/pypoetry/virtualenvs/teamproj-ilPeYRYx-py3.12/lib/python3.12/site-packages/pandas/core/series.py:1130, in Series.__getitem__(self, key)
#    1127     return self._values[key]
#    1129 elif key_is_scalar:
# -> 1130     return self._get_value(key)
#    1132 # Convert generator to list before going through hashable part
#    1133 # (We will iterate through the generator there to check for slices)
#    1134 if is_iterator(key):
#
# File ~/.cache/pypoetry/virtualenvs/teamproj-ilPeYRYx-py3.12/lib/python3.12/site-packages/pandas/core/series.py:1246, in Series._get_value(self, label, takeable)
#    1243     return self._values[label]
#    1245 # Similar to Index.get_value, but we do not fall back to positional
# -> 1246 loc = self.index.get_loc(label)
#    1248 if is_integer(loc):
#    1249     return self._values[loc]
#
# File ~/.cache/pypoetry/virtualenvs/teamproj-ilPeYRYx-py3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'city_code1'

# %%
with engine.connect() as conn:
    result = conn.execute(table.select())
    for row in result:
        print(row)

engine.url
# Out:
# postgresql+psycopg2://postgres:***@localhost:5432/postgres

# %%
import numpy as np
import faiss

embeddings = np.array(embeddings).astype("float32")

dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

query = "부산"
query_emb = client.embeddings.create(
    model="text-embedding-3-small",
    input=query
).data[0].embedding
query_emb = np.array([query_emb], dtype="float32")

# FAISS 검색
D, I = index.search(query_emb, k=3)
print("\n[검색어]", query)
for rank, idx in enumerate(I[0]):
    print(f"{rank+1}위: {final_df.iloc[idx]['시도_시군구']} (거리: {D[0][rank]:.4f})")
# Out:
# [검색어] 부산
# 1위: 부산광역시  (거리: 0.6525)
# 2위: 부산광역시 남구 (거리: 0.8496)
# 3위: 부산광역시 연제구 (거리: 0.8869)
