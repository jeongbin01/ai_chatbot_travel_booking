# %%
[
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01010100",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "국립공원"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01010200",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "도립공원"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01010300",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "군립공원"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01010400",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "산"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01010500",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "자연생태관광지"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01010600",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "자연휴양림"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01010700",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "수목원"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01010800",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "폭포"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01010900",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "계곡"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01011000",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "약수터"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01011100",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "해안절경"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01011200",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "해수욕장"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01011300",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "섬"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01011400",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "항구/포구"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01011600",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "등대"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01011700",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "호수"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01011800",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "강"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0101",
        "cat3": "A01011900",
        "cat1Nm": "자연",
        "cat2Nm": "자연관광지",
        "cat3Nm": "동굴"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0102",
        "cat3": "A01020100",
        "cat1Nm": "자연",
        "cat2Nm": "관광자원",
        "cat3Nm": "희귀동.식물"
    },
    {
        "contentTypeId": "12",
        "cat1": "A01",
        "cat2": "A0102",
        "cat3": "A01020200",
        "cat1Nm": "자연",
        "cat2Nm": "관광자원",
        "cat3Nm": "기암괴석"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02010100",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "고궁"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02010200",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "성"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02010300",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "문"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02010400",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "고택"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02010500",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "생가"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02010600",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "민속마을"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02010700",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "유적지/사적지"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02010800",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "사찰"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02010900",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "종교성지"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0201",
        "cat3": "A02011000",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "역사관광지",
        "cat3Nm": "안보관광"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0202",
        "cat3": "A02020200",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "휴양관광지",
        "cat3Nm": "관광단지"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0202",
        "cat3": "A02020300",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "휴양관광지",
        "cat3Nm": "온천/욕장/스파"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0202",
        "cat3": "A02020400",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "휴양관광지",
        "cat3Nm": "이색찜질방"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0202",
        "cat3": "A02020500",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "휴양관광지",
        "cat3Nm": "헬스투어"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0202",
        "cat3": "A02020600",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "휴양관광지",
        "cat3Nm": "테마공원"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0202",
        "cat3": "A02020700",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "휴양관광지",
        "cat3Nm": "공원"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0202",
        "cat3": "A02020800",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "휴양관광지",
        "cat3Nm": "유람선/잠수함관광"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0203",
        "cat3": "A02030100",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "체험관광지",
        "cat3Nm": "농.산.어촌 체험"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0203",
        "cat3": "A02030200",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "체험관광지",
        "cat3Nm": "전통체험"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0203",
        "cat3": "A02030300",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "체험관광지",
        "cat3Nm": "산사체험"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0203",
        "cat3": "A02030400",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "체험관광지",
        "cat3Nm": "이색체험"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0203",
        "cat3": "A02030600",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "체험관광지",
        "cat3Nm": "이색거리"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0204",
        "cat3": "A02040400",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "산업관광지",
        "cat3Nm": "발전소"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0204",
        "cat3": "A02040600",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "산업관광지",
        "cat3Nm": "식음료"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0204",
        "cat3": "A02040800",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "산업관광지",
        "cat3Nm": "기타"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0204",
        "cat3": "A02040900",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "산업관광지",
        "cat3Nm": "전자-반도체"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0204",
        "cat3": "A02041000",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "산업관광지",
        "cat3Nm": "자동차"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0205",
        "cat3": "A02050100",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "건축/조형물",
        "cat3Nm": "다리/대교"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0205",
        "cat3": "A02050200",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "건축/조형물",
        "cat3Nm": "기념탑/기념비/전망대"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0205",
        "cat3": "A02050300",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "건축/조형물",
        "cat3Nm": "분수"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0205",
        "cat3": "A02050400",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "건축/조형물",
        "cat3Nm": "동상"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0205",
        "cat3": "A02050500",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "건축/조형물",
        "cat3Nm": "터널"
    },
    {
        "contentTypeId": "12",
        "cat1": "A02",
        "cat2": "A0205",
        "cat3": "A02050600",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "건축/조형물",
        "cat3Nm": "유명건물"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02060100",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "박물관"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02060200",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "기념관"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02060300",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "전시관"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02060400",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "컨벤션센터"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02060500",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "미술관/화랑"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02060600",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "공연장"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02060700",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "문화원"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02060800",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "외국문화원"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02060900",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "도서관"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02061000",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "대형서점"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02061100",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "문화전수시설"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02061200",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "영화관"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02061300",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "어학당"
    },
    {
        "contentTypeId": "14",
        "cat1": "A02",
        "cat2": "A0206",
        "cat3": "A02061400",
        "cat1Nm": "인문(문화/예술/역사)",
        "cat2Nm": "문화시설",
        "cat3Nm": "학교"
    }, 
]
